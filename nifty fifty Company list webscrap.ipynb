# %%
import requests
ht=requests.get('https://economictimes.indiatimes.com/indices/nifty_50_companies')

# %%
print(ht.status_code)
print(ht.ok)
# Out:
# 200
# True

# %%
from bs4 import BeautifulSoup
html_sp=BeautifulSoup(ht.content,'html.parser')

# %%
html_sp.title.string
# Out:
# 'Nifty 50 Live | NSE Nifty 50 Index Today - S&P CNX Nifty - The Economic Times'

# %%
html_sp
# Out:
# <!DOCTYPE html>
# ...

# %%
html_sp.select('.ddMenu')
# Out:
# [<div class="ddMenu"><a href="https://market.android.com/details?id=com.et.reader.activities" onclick="ga('send','event','ET-TopNav','More','https://market.android.com/details?id=com.et.reader.activities')" rel="nofollow" target="_blank">ET Android App</a><a href="http://itunes.apple.com/us/app/the-economic-times/id474766725?ls=1&amp;mt=8" onclick="ga('send','event','ET-TopNav','More','http://itunes.apple.com/us/app/the-economic-times/id474766725?ls=1&amp;mt=8')" rel="nofollow" target="_blank">ET iPhone App</a><a href="http://itunes.apple.com/us/app/the-economic-times-for-ipad/id479227473?ls=1&amp;mt=8" onclick="ga('send','event','ET-TopNav','More','http://itunes.apple.com/us/app/the-economic-times-for-ipad/id479227473?ls=1&amp;mt=8')" rel="nofollow" target="_blank">ET iPad App</a><a href="https://play.google.com/store/apps/details?id=com.et.wealth&amp;hl=en" onclick="ga('send','event','ET-TopNav','More','https://play.google.com/store/apps/details?id=com.et.wealth&amp;hl=en')" rel="n
# ...
